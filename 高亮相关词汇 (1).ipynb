# %%
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt

# %%
# 加载模型
model = KeyedVectors.load_word2vec_format('50thousand.txt')

# %%
word_embeddings = model.vectors
words = model.index_to_key

# %%
# 找到词语的位置
word_index = words.index("solvent")

# 使用 t-SNE 进行降维
tsne = TSNE(n_components=2, random_state=42)
tsne_embeddings = tsne.fit_transform(word_embeddings)

# %%
# 计算 "perovskite" 与其他词语之间的余弦相似性
cosine_similarities = cosine_similarity(word_embeddings, [word_embeddings[word_index]])

# %%
# 可视化词向量图
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=cosine_similarities.ravel(), cmap='Blues', alpha=0.5)

# 高亮显示 "perovskite"
plt.scatter(tsne_embeddings[perovskite_index, 0], tsne_embeddings[word_index, 1], c='red', marker='*', s=100, label='Perovskite')

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Word Embeddings with Cosine Similarity')
plt.colorbar(label='Cosine Similarity')  # 添加颜色条
plt.legend()

# plt.plot(x, y, 'bo-')
# plt.axis([-40, 100, -60, 60])

plt.savefig('word_embeddings_visualization_all.png') 
plt.show()

# %%
# 可视化词向量图
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图
colors = plt.cm.Blues(cosine_similarities.ravel())  # 将二维数组展平为一维，并根据余弦相似性设置颜色深浅
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=colors, alpha=0.5)


plt.scatter(tsne_embeddings[word_index, 0], tsne_embeddings[perovskite_index, 1], c='red', marker='*', s=100, label='solvent')

# 只显示余弦相似性大于0.5的点
threshold_similarity = 0.55
for i, similarity in enumerate(cosine_similarities):
    if similarity > threshold_similarity:
        plt.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], c='violet', alpha=0.5)

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Word Embeddings with Cosine Similarity (Cosine Similarity > 0.5)')
plt.legend()

# 添加颜色条
cbar = plt.colorbar()
cbar.set_label('Cosine Similarity')
plt.savefig('word_embeddings_visualization.png')  # 可以将文件名修改为您想要的文件名和路径

plt.show()

# %%
# 找到 "ETL" 的位置
etl_index = words.index("ETL")
# 可视化词向量图
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图
colors = plt.cm.Blues(cosine_similarities.ravel())  # 将二维数组展平为一维，并根据余弦相似性设置颜色深浅
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=colors, alpha=0.5)

# 只显示余弦相似性大于0.5的点
threshold_similarity = 0.55
for i, similarity in enumerate(cosine_similarities):
    if similarity > threshold_similarity:
        plt.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], c='violet', alpha=0.5)


plt.scatter(tsne_embeddings[perovskite_index, 0], tsne_embeddings[word_index, 1], c='red', marker='*', s=100, label='solvent')
# 高亮显示 "ETL"
plt.scatter(tsne_embeddings[etl_index, 0], tsne_embeddings[etl_index, 1], c='green', marker='^', s=100, label='ETL')

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Word Embeddings with Cosine Similarity (Cosine Similarity > 0.5)')
plt.legend()

# 添加颜色条
cbar = plt.colorbar()
cbar.set_label('Cosine Similarity')
plt.savefig('word_embeddings_visualization.png')  # 可以将文件名修改为您想要的文件名和路径

plt.show()

# %%
# 找到 "ETL" 的位置
etl_index = words.index("ETL")

# 计算 "ETL" 与其他词语之间的余弦相似性
cosine_similarities_etl = cosine_similarity(word_embeddings, [word_embeddings[etl_index]])

# 可视化词向量图
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=cosine_similarities.ravel(), cmap='Blues', alpha=0.5)

# 高亮显示 "perovskite"
plt.scatter(tsne_embeddings[perovskite_index, 0], tsne_embeddings[perovskite_index, 1], c='red', marker='*', s=100, label='Perovskite')

# 高亮显示 "ETL"
plt.scatter(tsne_embeddings[etl_index, 0], tsne_embeddings[etl_index, 1], c='green', marker='^', s=100, label='ETL')

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Word Embeddings with Cosine Similarity')
plt.colorbar(label='Cosine Similarity')  # 添加颜色条
plt.legend()
plt.savefig('word_embeddings_visualization_all.png') 
plt.show()

# %%
# 找到 "ETL" 的位置
etl_index = words.index("ETL")

# 计算 "ETL" 与其他词语之间的余弦相似性
cosine_similarities_etl = cosine_similarity(word_embeddings, [word_embeddings[etl_index]])

# 可视化词向量图
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图
colors = plt.cm.Blues(cosine_similarities.ravel())  # 将二维数组展平为一维，并根据余弦相似性设置颜色深浅
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=colors, alpha=0.5)

# 高亮显示 "perovskite"
threshold_similarity_perovskite = 0.5
for i, similarity in enumerate(cosine_similarities):
    if similarity > threshold_similarity_perovskite:
        plt.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], c='purple', alpha=0.5)

# 高亮显示 "ETL"
threshold_similarity_etl = 0.5
for i, similarity in enumerate(cosine_similarities_etl):
    if similarity > threshold_similarity_etl:
        plt.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], c='blue', alpha=0.5)

plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Word Embeddings with Cosine Similarity')
# plt.colorbar(label='Cosine Similarity (Perovskite)')
# plt.colorbar(label='Cosine Similarity (ETL)')
plt.legend()
plt.savefig('word_embeddings_visualization_all.png') 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
